# %%
import pandas as pd
from pathlib import Path

# %%
bitsum1_csv = Path (r"C:\Users\admin\Desktop\FinTech\FinTech2022_Module3_Financial Analysis_Pandas\02-Bitcoin_Summary_Statistics\Resources\bitcoin_1.csv")

# %%
bit_df1 = pd.read_csv(
    bitsum1_csv,
    index_col="Timestamp",
    parse_dates=True,
    infer_datetime_format=True
)
bit_df1.head()
# Out:
#                      Close
# Timestamp
# 2015-01-01 00:00:00  314.0
# 2015-01-01 00:01:00  314.0
# 2015-01-01 00:02:00  314.0
# 2015-01-01 00:03:00  314.0
# 2015-01-01 00:04:00  313.9

# %%
bit_df1.tail()
# Out:
#                       Close
# Timestamp
# 2015-12-31 23:53:00  435.66
# 2015-12-31 23:54:00  435.21
# 2015-12-31 23:56:00  435.17
# 2015-12-31 23:57:00  435.10
# 2015-12-31 23:58:00  435.11

# %%
bit_df1.isnull().sum()
# Out:
# Close    0
# dtype: int64

# %%
bit_df1["Close"].dtypes
# Out:
# dtype('float64')

# %%
bitsum2_csv = Path (r"C:\Users\admin\Desktop\FinTech\FinTech2022_Module3_Financial Analysis_Pandas\02-Bitcoin_Summary_Statistics\Resources\bitcoin_2.csv")

# %%
bit_df2 = pd.read_csv(
    bitsum2_csv,
    index_col="Timestamp",
    parse_dates=True,
    infer_datetime_format=True
)
bit_df2.head()
# Out:
#                       Close
# Timestamp
# 2015-01-07 20:24:00  360.00
# 2015-01-07 20:27:00  276.34
# 2015-01-07 20:28:00  271.60
# 2015-01-07 20:29:00  344.67
# 2015-01-07 20:30:00  305.38

# %%
bit_df2.tail()
# Out:
#                       Close
# Timestamp
# 2015-12-31 23:55:00  437.02
# 2015-12-31 23:56:00  437.07
# 2015-12-31 23:57:00  436.03
# 2015-12-31 23:58:00  436.13
# 2015-12-31 23:59:00  436.12

# %%
bit_df2.isnull().sum()
# Out:
# Close    0
# dtype: int64

# %%
bit_df2["Close"].dtypes
# Out:
# dtype('float64')

# %%
bit_df1.describe()
# Out:
#                Close
# count  372773.000000
# mean      274.423996
# std        61.778634
# min       153.100000
# 25%       233.850000
# 50%       248.950000
# 75%       288.820000
# max       501.960000

# %%
bit_df2.describe()
# Out:
#                Close
# count  440797.000000
# mean      275.956285
# std        60.728446
# min       109.940000
# 25%       235.810000
# 50%       250.540000
# 75%       289.260000
# max       499.260000

# %%
bit_df1.plot(figsize=(10,5), title="Bitcoin_1", color="blue")
# Out:
# <AxesSubplot: title={'center': 'Bitcoin_1'}, xlabel='Timestamp'>

# %%
bit_df2.plot(figsize=(10,5), title="Bitcoin_2", color="orange")
# Out:
# <AxesSubplot: title={'center': 'Bitcoin_2'}, xlabel='Timestamp'>

# %%
bit_df1["Close"].plot(legend=True, figsize=(15,7), title="Bitcoin_1 v. Bitcoin_2", color="blue", label="BTC 1")
bit_df2["Close"].plot(legend=True, figsize=(15,7), color="orange", label="BTC 2")
# Out:
# <AxesSubplot: title={'center': 'Bitcoin_1 v. Bitcoin_2'}, xlabel='Timestamp'>

# %%
#loc["2015-01-26": "2015-01-31"]
bit_df1["Close"].loc["2015-01-26": "2015-01-31"].plot(legend=True, figsize=(15,7), title="Bitcoin_1 v. Bitcoin_2", color="blue", label="BTC 1")
bit_df2["Close"].loc["2015-01-26": "2015-01-31"].plot(legend=True, figsize=(15,7), color="orange", label="BTC 2")
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_6364\3728321610.py:3: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   bit_df2["Close"].loc["2015-01-26": "2015-01-31"].plot(legend=True, figsize=(15,7), color="orange", label="BTC 2")
# <AxesSubplot: title={'center': 'Bitcoin_1 v. Bitcoin_2'}, xlabel='Timestamp'>

# %%
#loc["2015-01-26":"2015-01-31"]
bit_df1["Close"].loc["2015-01-31"].plot(legend=True, figsize=(15,7), title="Bitcoin_1 v. Bitcoin_2", color="blue", label="BTC 1")
bit_df2["Close"].loc["2015-01-31"].plot(legend=True, figsize=(15,7), color="orange", label="BTC 2")
# Out:
# <AxesSubplot: title={'center': 'Bitcoin_1 v. Bitcoin_2'}, xlabel='Timestamp'>

# %%
bit_df1["2015-01-31 00:04:00": "2015-01-31 00:06:00"]
# Out:
#                       Close
# Timestamp
# 2015-01-31 00:04:00  226.50
# 2015-01-31 00:05:00  226.68
# 2015-01-31 00:06:00  226.69

# %%
#loc["2015-01-26":"2015-01-31"]
bit_df1["Close"].loc["2015-01-31 18:00:00": "2015-01-31 21:00:00"].plot(legend=True, figsize=(15,10), title="Bitcoin_1 v. Bitcoin_2", color="blue", label="BTC 1")
bit_df2["Close"].loc["2015-01-31 18:00:00": "2015-01-31 21:00:00"].plot(legend=True, figsize=(15,10), color="orange", label="BTC 2")
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_6364\2579883572.py:2: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   bit_df1["Close"].loc["2015-01-31 18:00:00": "2015-01-31 21:00:00"].plot(legend=True, figsize=(15,10), title="Bitcoin_1 v. Bitcoin_2", color="blue", label="BTC 1")
# <AxesSubplot: title={'center': 'Bitcoin_1 v. Bitcoin_2'}, xlabel='Timestamp'>
